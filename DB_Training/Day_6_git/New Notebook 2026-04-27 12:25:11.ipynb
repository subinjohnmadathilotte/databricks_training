# %%
github tp config databricks to git

1 new repo

data bricks
2.create a git folfer with repo url
3.git config
4 push the changes

# %%
https://github.com/subinjohnmadathilotte/databricks_training.git
