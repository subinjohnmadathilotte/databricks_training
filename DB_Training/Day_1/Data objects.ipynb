-- %%
create schema if not exists dev.subin;

-- %%
use catalog dev;
use schema subin;

-- %%
create table test (id int, name string);

-- %%
insert into dev.subin.test values (1, 'test');

-- %%
select * from test

-- %%
alter table test add primary key (id);

-- %%
alter table dev.subin.test alter column id set not null

-- %%
insert into dev.subin.test values (1, 'test');

-- %%
select * from test

-- %% [markdown]
-- ![](/Volumes/dev/subin/test_volumne_image/Screenshot 2026-04-20 123336.png)
