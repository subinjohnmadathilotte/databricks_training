# %%
print(1)

# %% [markdown]
# ## Types of computes

# %%
# %sql

select "run Sql"

# %%
# %sql
select * from samples.tpch.orders

# %%
# %sql
select o_orderdate, sum(o_custkey) as sum_custkey
from samples.tpch.orders
group by o_orderdate
order by o_orderdate
