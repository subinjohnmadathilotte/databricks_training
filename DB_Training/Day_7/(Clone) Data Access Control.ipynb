# %%
dev.naval.customers_continentsyntax

grant privileges on object object_name to user/group/service


revoke privilege on object object_name from  user/group/service

# %%
# %sql
--grant usage on catalog dev to `account users`;
grant usage on schema dev.naval to `dataeng`;
grant select on table dev.naval.demo to `dataeng`
