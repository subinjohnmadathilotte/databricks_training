-- %%
--Incrementall load
COPY INTO ---Use this

--Streaming
COPY INTO ,structured streaming, autoloader

-- %%
COPY INTO ---to handel the incremental data

-- %%
Insert into, copy into, merge into

-- %%
COPY INTO: handle the incremental data

-- %%
create table dev.naval.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/sales.csv")

-- %%
create table if not exists dev.naval.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/sales.csv")

-- %%
create or replace table dev.naval.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/")

-- %%
select * from dev.naval.sales_b

-- %%
insert into dev.naval.sales_b (select order_id, customer_id, transaction_id, product_id, quantity, discount_amount, total_amount, to_date(order_date, 'MM/dd/yy') as order_date, NULL as order_date_2, _rescued_data from read_files ("/Volumes/dev/naval/project/sales/"))

-- %%
select * from dev.naval.sales_b

-- %%
insert into dev.naval.sales_b select *from read_files ("/Volumes/dev/naval/project/sales/sales2.csv")

-- %%
%python
#df=spark.read.csv("/Volumes/dev/naval/project/sales/")
#df.write.mode("overwrite").saveAsTable("tblname")
#df.write.mode("append").saveAsTable("tblname")

-- %%
COPY into: 
1.Exactly once.
2. Idempotent 
3. Rocks db (internally )
4. structured stremaing ( pyspark ) == alternative -- copy into sql command

-- %%
CREATE TABLE IF NOT EXISTS <catalog>.<schema>.booking_updates_schemaless;

COPY INTO <catalog>.<schema>.booking_updates_schemaless
FROM '/Volumes/<catalog>/<schema>/<volume>/wanderbricks/booking_updates'
FILEFORMAT = JSON
FORMAT_OPTIONS ('mergeSchema' = 'true', 'multiLine' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- %%
create table if not exists dev.naval.sales_copy (order_id int, customer_id int , transaction_id int, product_id int, quantity int, discount_amount double, total_amount double, order_date string)

-- %%
create table if not exists dev.naval.month_copy

-- %%
COPY INTO dev.naval.month_copy 
FROM '/Volumes/dev/naval/project/incremental/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- %%
select * from dev.naval.month_copy
