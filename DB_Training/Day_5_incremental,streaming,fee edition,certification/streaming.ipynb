# %%
Structired streaming is open source,
data bricks has auto loader

# %%
delta live tables to habndle batch, incrmena, staming, autoloder

open source now

# %%
delta live tables ----pipelines ---- lakeflow spark declarative pipelines

# %%
df = spark.read.csv("path")
df.write.saveAsTable("Tablename")

strem

df.spark.readStream.csv("path")
df.writeStream.saveAsTable("Tablename"

# %%
whenever we are doing a action in streaming
by default it trigger and it hits staorge account every 1/2 sec =0.5 millisecond
