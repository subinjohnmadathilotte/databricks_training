# %%
# --Incrementall load
# COPY INTO ---Use this

# --Streaming
# COPY INTO ,structured streaming, autoloader

# %%
# COPY INTO ---to handel the incremental data

# %%
# %sql
create table if not exists dev.subin.sales_copy

# %%
# %sql
COPY INTO dev.subin.sales_copy 
FROM '/Volumes/dev/naval/project/sales/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('mergeSchema' = 'true','header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');
