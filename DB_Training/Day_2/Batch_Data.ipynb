# %%
# %sql
I) Cloud Object storage (S3, ADLS, GCS, Volume)
Volume:
csv,json,parquet, avro, txt, pdf, excel, xml, xls...etc

a. Batch 
          pyspark=== df 
          sql ==== CTAS
          UI :create table button

# %%
# %sql
select * from read_files("/Volumes/dev/naval/raw/financial_dataset.csv")

# %%
# %sql
create table  dev.subin.financial_sql as
select * from read_files("/Volumes/dev/naval/raw/financial_dataset.csv")

# %%
# %sql
select * from dev.subin.financial_sql

# %%
# %sql
desc detail dev.subin.financial_sql

# %%
# %sql
select * from read_files("/Volumes/dev/naval/raw/drivers.json")

# %%
# %sql
create table dev.subin.f1_drivers_sql as
select * from read_files("/Volumes/dev/naval/raw/drivers.json")

# %%
# %sql
select * from dev.subin.f1_drivers_sql

# %%
# %python
df =  spark.read.csv("/Volumes/dev/naval/raw/financial_dataset.csv",header = True,inferSchema = True)

# %%
# %python
df.filter("TransactionType = 'Deposit'").display()

# %%
# %python
df.filter("TransactionType = 'Withdrawal'").explain()

# %%
# %python
from pyspark.sql.functions import *

# %%
df1 = df.withColumn("Ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))

# %%
df.write.mode("overwrite").saveAsTable("dev.subin.spark_df")

# %%
def add_columns(df):
    return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))

# %%
df1=add_columns(df)
df1.write.mode("overwrite").saveAsTable("dev.subin.spark_df_1")

# %%
df.withColumn("test",lit("subin")).display()
