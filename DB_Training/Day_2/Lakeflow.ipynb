-- %%
LakeFlow : how to get the data to the platform, it helps to injest the data.
1.	Lakeflow connect
2.	Lakeflow pipeline
3.	Lakeflow jobs

-- %%
lakeflow connect

.... Cloud oibjetc storage (s3,ADLS,GCS,volumne)
    volumne :
    csv,json,paruqet,avro,txt pdf. excel etc

    a.Batch
        pyspark ===df
        sql====CTAS
    b.Incremental
    c.streaming

....Saas, DB or data wearhouse
    -----Data bricks connector (native)
    -----Fivetran (200 + source)
