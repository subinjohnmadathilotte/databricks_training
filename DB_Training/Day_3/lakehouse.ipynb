# %%
# %sql
create table dev.subin.emp (id int, name string, city string);

# %%
# %sql
desc extended dev.subin.emp

# %%
# %sql
Internals of delta

parquet (Data)
+
_delta_logs
1. crc (desc detial)
2. json (desc history)
3. checkpoint parquet files

# %%
# %sql
desc detail dev.subin.emp

# %%
# %sql
desc history dev.subin.emp

# %%
# %sql
insert into dev.subin.emp values (1, 'subin', 'Trivandrum');

# %%
# %sql
insert into dev.subin.emp values (2,'Justin','kerala'),(3,'Rahul','Bengaluru')

# %%
# %sql
select * from dev.subin.emp

# %%
# %sql
update dev.subin.emp
set city ='Delhi'
where id = 1

# %%
# %sql
select * from dev.subin.emp version as of 2

# %%
# %sql
select * from dev.subin.emp timestamp as of '2026-04-22T08:38:36.000+00:00'

# %%
# %sql
insert into dev.subin.emp values (4,'Ravi','Mumbai');
    
select * from dev.subin.emp

# %%
# %sql
restore table dev.subin.emp to version as of 2

# %%
# %sql
select * from dev.subin.emp
